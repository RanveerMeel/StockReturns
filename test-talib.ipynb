# %%
import talib as ta
import pandas as pd
import datetime as dt
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tcs_ns = pd.read_csv("data/TCS.NS.csv", parse_dates = True)
tcs_ns["date_x"] = [dt.datetime.strptime(d,'%d-%m-%Y').date() for d in tcs_ns["Date"]]

# %%
#tcs_ns["SMA"] = ta.SMA(tcs_ns["Close"], timeperiod=40)
tcs_ns["SMA 30"] = np.round(tcs_ns["Adj Close"].rolling(window = 30, center = False).mean(), 2)

# %%
tcs_ns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 14 columns):
# Date          1232 non-null object
# Open          1229 non-null float64
# High          1229 non-null float64
# Low           1229 non-null float64
# Close         1229 non-null float64
# Adj Close     1229 non-null float64
# Volume        1229 non-null float64
# Unnamed: 7    0 non-null float64
# Unnamed: 8    0 non-null float64
# Unnamed: 9    0 non-null float64
# date_x        1232 non-null object
# SMA           200 non-null float64
# 30d           1113 non-null float64
# SMA 30        1113 non-null float64
# dtypes: float64(12), object(2)
# memory usage: 134.8+ KB

# %%
pylab.rcParams['figure.figsize'] = (15, 9)
plt.plot_date(tcs_ns["date_x"],tcs_ns["Adj Close"],'g-')
plt.plot_date(tcs_ns["date_x"],tcs_ns["SMA 30"],'r-')
plt.plot_date(tcs_ns["date_x"],tcs_ns["Adj Close"]-tcs_ns["SMA 30"],'r-')
